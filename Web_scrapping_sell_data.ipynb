# %%
def create_url(zipcode, filter=None):

    # Creating Zillow URL based on the filter.
 region_id={94109:97564,94565:97771,94501:97711,94110:97565,94536:97743,95123:97991,95035:97940,94544:97751
,94568:97774,95051:97952,94509:97717,94122:97576,94541:97748,94538:97745,95076:97970,94513:97721
,94587:97792,95014:97926,95112:97980,94080:97545,94112:97567,94087:97549,95125:97993,94086:97548
,94806:97852,94553:97760,94015:97506,95008:97920,95020:97931,94115:97569,94117:97571,94102:97557
,94121:97575,94611:97813,95060:97958,94550:97757,94577:97783,94118:97572,94546:97753,94403:97703
,94103:97558,94114:97568,95124:97992,94539:97746,94107:97562,94010:97501,94566:97772,94605:97807
,95037:97942,94066:97540,94601:97803,94610:97812,94025:97516,94521:97729,95136:98004,95127:97995
,95111:97979,95062:97960,95126:97994,94901:97858,94606:97808,94040:97527,94608:97810,94404:97704
,94116:97570,94804:97850,94560:97766,95050:97951,94551:97758,94582:97788,94578:97784,94044:97531
,94123:97577,94523:97731,94303:97693,95129:97997,94583:97789,94531:97739,94561:97767,95128:97996
,95134:98002,94061:97535,94401:97701,94043:97530,94131:97585,94014:97505,94520:97728,95116:97984
,94133:97587,94941:97881,94526:97734,94588:97793,94070:97542,95120:97988,94903:97859,94602:97804
,95122:97990,95070:97966,94063:97537,94306:97696,95132:98000,94607:97809,94555:97761,95148:98011
,94134:97588,94530:97738,94549:97756,94002:97498,95118:97986,94596:97799,94124:97578,94597:97800
,94132:97586,95032:97938,94598:97801,95117:97985,94609:97811,95003:97915,94402:97702,94545:97752
,94062:97536,94518:97726,94595:97798,94603:97805,94619:97820,94801:97847,94612:97814,95121:97989
,95131:97999,94621:97822,94580:97786,94704:97838,94947:97885,94803:97849,94030:97521,94085:97547
,94703:97837,94547:97754,94089:97551,95133:98001,95054:97955,94506:97714,94706:97840,94024:97515
,94105:97560,94702:97836,94301:97691,94127:97581,94022:97513,94618:97819,94563:97769,94108:97563
,94564:97770,95135:98003,94949:97887,94579:97785,94041:97528,94519:97727,94945:97883,95110:97978
,94019:97510,94705:97839,94505:39968,94960:97896,94920:97865,95138:98006,94965:97899,94507:97715
,94556:97762,95066:97964,95010:97922,94709:97843,94805:97851,95030:97936,94707:97841,94904:97860
,94502:97712,94542:97749,94517:97725,94065:97539,94552:97759,94158:97610,95130:97998,94708:97842
,95073:97968,95006:97918,94305:97695,94925:97869,95018:97929,94930:97874,94939:97879,95033:97939
,94710:97844,94572:97778,95065:97963,95119:97987,95019:97930,95005:97917,94028:97519,94027:97518
,94111:97566,95046:97950,94304:97694,95139:98007,94005:97500,94018:97509,94525:97733,95113:97981
,94038:97525,94037:97524,94511:97719,94957:97895,94956:97894,95002:97914,94020:97511,94973:97904
,94937:97877,94060:97534,94586:97791,94104:97559,94528:97736,94933:97876,95064:97962,95017:97928
,94514:97722,94970:97901,94548:97755,95007:97919,94938:97878,95041:97945,94946:97884,94963:97897
,94964:97898,94971:97902,94929:97873,95140:98008,94516:97724,94074:97544,94569:97775,94021:97512
,94950:97888,95141:98009}

 p=region_id.get(zipcode)
 print(p)
 if filter == "rent":
   #url ="https://www.zillow.com/homes/?searchQueryState={\"regionSelection\":[{\"regionId\":"+str(p)",\"regionType\":7}],\"filterState\":{\"fr\":{\"value\":true},\"fsba\":{\"value\":false},\"fsbo\":{\"value\":false},\"nc\":{\"value\":false},\"cmsn\":{\"value\":false},\"auc\":{\"value\":false},\"fore\":{\"value\":false},\"pmf\":{\"value\":false},\"pf\":{\"value\":false}}}"
   url="https://www.zillow.com/homes/?searchQueryState={regionSelection:[{regionId:"+str(p)+",regionType:7}],filterState:{fr:{value:true},fsba:{value:false},fsbo:{value:false},nc:{value:false},cmsn:{value:false},auc:{value:false},fore:{value:false},pmf:{value:false},pf:{value:false}}}"
 elif filter == "sold":
     url = 'https://www.zillow.com/homes/?searchQueryState={"regionSelection":[{"regionId":{0},"regionType":7}],"filterState":{"rs":{"value":true},"fsba":{"value":false},"fsbo":{"value":false},"nc":{"value":false},"cmsn":{"value":false},"auc":{"value":false},"fore":{"value":false},"pmf":{"value":false},"pf":{"value":false}}}'.format(region_id.get(zipcode))
 else:
     url = "https://www.zillow.com/homes/"+str(zipcode)+"/?searchQueryState={\"regionSelection\":[{\"regionId\":"+str(p)+",\"regionType\":7}],\"filterState\":{\"sort\":{\"value\":\"globalrelevanceex\"},\"con\":{\"value\":false},\"mf\":{\"value\":false},\"manu\":{\"value\":false},\"land\":{\"value\":false},\"tow\":{\"value\":false},\"apa\":{\"value\":false}}}"
 print(url)
 return url

# %%
def list_of_url(url):
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(req).read()

    # Creating a BeautifulSoup object of the html page for easy extraction of data.

    soup = BS(webpage,'html.parser')
    #print (soup.title)
    #html=soup.prettify()
    r= url.split(":")
    p=(r[3]).split(",")
    t=p[0]
    abc=soup.find('span',class_='result-count')
    abc=abc.string.split()
    abc=int(abc[0])
    abc

    pqr=[]
    pqr.append(url)
    l=mt.ceil(abc/40)
    while l!=1:
        pqr.append("https://www.zillow.com/homes/94536/?searchQueryState={\"pagination\":{\"currentPage\":"+str(l)+"},\"regionSelection\":[{\"regionId\":"+str(t)+",\"regionType\":7}],\"filterState\":{\"sort\":{\"value\":\"globalrelevanceex\"},\"con\":{\"value\":false},\"mf\":{\"value\":false},\"manu\":{\"value\":false},\"land\":{\"value\":false},\"tow\":{\"value\":false},\"apa\":{\"value\":false}}}")
        l=l-1

    return pqr

# %%
def data_return(url_input):

    import urllib.request 
    import urllib.parse
    import urllib.error
    import ssl
    from urllib.request import Request, urlopen
    from bs4 import BeautifulSoup as BS
    import pandas as pd
    import math as mt
    # For ignoring SSL certificate errors
    ctx = ssl.create_default_context()
    ctx.check_hostname = False
    ctx.verify_mode = ssl.CERT_NONE

    ls=[]

    #url="https://www.zillow.com/homedetails/333-Sunnyslope-Dr-Fremont-CA-94536/25020787_zpid/"
    url_open=Request(url_input, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(url_open).read()
    soup = BS(webpage,'html.parser')
    #item_found=[Year(0),HOA(1),Heating(2),Cooling(3),parrking(4),Price/Sqft(5),Price(6),'bedroom'(7),bathroom(8),address(9),
    #house_size(10),lot_size(11),Day_on_zillow(12),url(13)]
    item_found=['None','None','None','None','None','None','None','None','None','None','None','None','None','None']
    item_found[13]=url_input

    for tag in soup.find_all('div',class_='ds-price-change-address-row'):
        item_found[9]=tag.get_text()
    for tag in soup.find_all('div',class_='sc-158alvd-1 hYWQsX'):
        #item_found[10]=tag.get_text()
        print(tag.get_text())
    for tag in soup.find_all('div',class_='Text-aiai24-0 sc-158alvd-2 evMekH'):
        item_found[12]=tag.get_text()    

    for tag in soup.find_all('li', class_="ds-home-fact-list-item"):
        cleaned_tag=tag.get_text().strip()
        if(cleaned_tag[0:4]=='Year'):
               item_found[0]=cleaned_tag.split(':')[1]
        if(cleaned_tag[0:3]=='HOA'):
            #HOA.append(cleaned_tag.split(':')[1])
            item_found[1]=cleaned_tag.split(':')[1]
        if(cleaned_tag[0:7]=='Heating'):
            #Heating.append(cleaned_tag.split(':')[1])
            item_found[2]=cleaned_tag.split(':')[1]
        if(cleaned_tag[0:7]=='Cooling'):
            #Cooling.append(cleaned_tag.split(':')[1])  
            item_found[3]=cleaned_tag.split(':')[1]
        if(cleaned_tag[0:7]=='Parking'):
            #Parking.append(cleaned_tag.split(':')[1])
            item_found[4]=cleaned_tag.split(':')[1]
        if(cleaned_tag[0:10]=='Price/sqft'):
            #Price_per_sqft.append(cleaned_tag.split(':')[1])    
            item_found[5]=cleaned_tag.split(':')[1]
        if(cleaned_tag[0:3]=='Lot'):
            item_found[11]=cleaned_tag.split(':')[1] 
        #print(cleaned_tag[0:8])  

    for tag in soup.find_all('span',class_="ds-value"):
        item_found[6]=tag.get_text()
    for tag in soup.find('div',class_="Text-aiai24-0 sc-qYsuA eRtvNE"):
        item_found[12]=tag  
        #print(tag.get_text())


    #for tag in soup.find_all('span',class_="Text-aiai24-0 ihhPyX"):
        #cleaned_tag=tag.get_text().strip()
        #print(cleaned_tag)
        #if(cleaned_tag[0:9]=='Bathrooms'):
            #item_found[7]=cleaned_tag.split(':')[1]
        #if(cleaned_tag[0:8]=='Bedrooms'):
            #item_found[8]=cleaned_tag.split(':')[1]
        #if(cleaned_tag[0:8]=='Lot size'):
           # item_found[11]=cleaned_tag.split(':')[1]
        #if(cleaned_tag[0:27]=='Total interior livable area'):
           # item_found[10]=cleaned_tag.split(':')[1]    
        #print(cleaned_tag[0:27])
        
        
    for tag in soup.find_all('span',class_="ds-bed-bath-living-area"):
        ls.append(tag.get_text().split("\n"))
        #print(cleaned_tag)
    item_found[7]=pd.Series(ls[0])[0]
    item_found[8]=pd.Series(ls[1])[0]
    item_found[10]=pd.Series(ls[2])[0]
  
    return item_found

# %%
import urllib.request 
import urllib.parse
import urllib.error
import ssl
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as BS
import pandas as pd
import math as mt
# For ignoring SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

zip_code=[94805,94801,94804,94803,94806]
urls=[]
links=[]
df = pd.DataFrame(columns=['Year','HOA','Heating','Cooling','parking','Price/Sqft','Price','bedroom','bathroom','address',
'house_size','lot_size','Day_on_zillow','url'])

for i in zip_code:
    url=create_url(i)
    lis_url=list_of_url(url)

    for i in lis_url :
        url_open=Request(i, headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urlopen(url_open).read()
        soup = BS(webpage,'html.parser')
        for tag in soup.find_all("article"):
            href = tag.find('a',class_="list-card-link")
            urls.append(href) 
            
for i in range(len(urls)):
    links.append((urls[i]['href']))

for i in links:
    tag_list=[]
    tag_list=data_return(i)
    df=df.append(pd.Series(tag_list,index=df.columns),ignore_index=True)
print(df)
# Out:
# 97851
# https://www.zillow.com/homes/94805/?searchQueryState={"regionSelection":[{"regionId":97851,"regionType":7}],"filterState":{"sort":{"value":"globalrelevanceex"},"con":{"value":false},"mf":{"value":false},"manu":{"value":false},"land":{"value":false},"tow":{"value":false},"apa":{"value":false}}}
# 97847
# https://www.zillow.com/homes/94801/?searchQueryState={"regionSelection":[{"regionId":97847,"regionType":7}],"filterState":{"sort":{"value":"globalrelevanceex"},"con":{"value":false},"mf":{"value":false},"manu":{"value":false},"land":{"value":false},"tow":{"value":false},"apa":{"value":false}}}
# 97850
# https://www.zillow.com/homes/94804/?searchQueryState={"regionSelection":[{"regionId":97850,"regionType":7}],"filterState":{"sort":{"value":"globalrelevanceex"},"con":{"value":false},"mf":{"value":false},"manu":{"value":false},"land":{"value":false},"tow":{"value":false},"apa":{"value":false}}}
# 97849
# https://www.zillow.com/homes/94803/?searchQueryState={"regionSelection":[{"regionId":97849,"regionType":7}],"filterState":{"sort":{"value":"globalrelevanceex"},"con":{"value":false},"mf":{"value":false},"manu":{"value":false},"land":{"value":false},"tow":{"value":false},"apa":{"value":false}}}
# 97852
# https://www.zillow.com/homes/94806/?searchQueryState={"regionSelection":[{"regionId":97852,"regionType":7}],"filterState":{"sort":{"value":"globalrelevanceex"},"con":{"value":false},"mf":{"value":false},"manu":{"value":false},"land":{"value":false},"tow":{"value":false},"apa":{"value":false}}}
#      Year   HOA     Heating  Cooling          parking Price/Sqft     Price  \
# 0    1954  None  Forced air     None         2 spaces       $375  $647,700
# 1    1918  None  Forced air  Central          No Data       $430  $529,000
# 2    1948  None  Forced air  Central  Attached Garage       $406  $668,000
# 3    1947  None  Forced air  Central  Attached Garage       $543  $499,000
# 4    1951  None  Forced air     None          1 space       $747  $699,000
# ..    ...   ...         ...      ...              ...        ...       ...
# 162  1964  None     No Data  No Data  Attached Garage       None  $573,420
# 163  1950  None     No Data  No Data          No Data       None  $453,002
# 164  1950  None       Other  No Data          1 space       None  $463,961
# 165  1950  None        Wall  No Data  Attached Garage       None  $444,127
# 166  1956  None  Forced air  No Data         2 spaces       None  $621,252
#
#     bedroom bathroom                                 address  \
# 0      3 bd     2 ba         733 40th St, Richmond, CA 94805
# 1      3 bd     2 ba      3914 Nevin Ave, Richmond, CA 94805
# 2      3 bd     2 ba     644 Humboldt St, Richmond, CA 94805
# 3      2 bd     1 ba         511 36th St, Richmond, CA 94805
# 4      2 bd     1 ba      6451 Hazel Ave, Richmond, CA 94805
# ..      ...      ...                                     ...
# 162    3 bd     2 ba    3083 Belfast Way, Richmond, CA 94806
# 163    3 bd     1 ba  4504 Mcglothen Way, Richmond, CA 94806
# 164    3 bd     1 ba       2009 Road 20, San Pablo, CA 94806
# 165    3 bd     1 ba        705 Banks Dr, Richmond, CA 94806
# 166    3 bd   2.5 ba       2576 Duke Ave, Richmond, CA 94806
#
#             house_size    lot_size Day_on_zillow  \
# 0    1,725 Square Feet  5,000 sqft         1 day
# 1    1,231 Square Feet  3,798 sqft         1 day
# 2    1,646 Square Feet  5,998 sqft        6 days
# 3      919 Square Feet  2,500 sqft         1 day
# 4      936 Square Feet  3,497 sqft        3 days
# ..                 ...         ...           ...
# 162  1,582 Square Feet  6,435 sqft      372 days
# 163  1,313 Square Feet  5,040 sqft      257 days
# 164    913 Square Feet  6,655 sqft      323 days
# 165  1,309 Square Feet  5,000 sqft      223 days
# 166  1,714 Square Feet  8,418 sqft      200 days
#
#                                                    url
# 0    https://www.zillow.com/homedetails/733-40th-St...
# 1    https://www.zillow.com/homedetails/3914-Nevin-...
# 2    https://www.zillow.com/homedetails/644-Humbold...
# 3    https://www.zillow.com/homedetails/511-36th-St...
# 4    https://www.zillow.com/homedetails/6451-Hazel-...
# ..                                                 ...
# 162  https://www.zillow.com/homedetails/3083-Belfas...
# 163  https://www.zillow.com/homedetails/4504-Mcglot...
# 164  https://www.zillow.com/homedetails/2009-Road-2...
# 165  https://www.zillow.com/homedetails/705-Banks-D...
# 166  https://www.zillow.com/homedetails/2576-Duke-A...
#
# [167 rows x 14 columns]

# %%
df.to_csv('Richmond_For_Sell.csv')

# %%
df
# Out:
#       0           1           2        3                      4       5   \
# 0   1965        None  Forced air    Other               2 spaces    $605
# 1   1955   $18/month  Forced air  Central               2 spaces    $679
# 2   1989        None  Forced air  Central                No Data    $766
# 3   1965        None  Forced air    Other               2 spaces    $605
# 4   1955   $18/month  Forced air  Central               2 spaces    $679
# 5   1963   $45/month  Forced air     None               2 spaces    $849
# 6   1983        None  Forced air  No Data               2 spaces    $727
# 7   1986        None  Forced air  Central               2 spaces    $826
# 8   1976        None  Forced air  Central        Attached Garage    $752
# 9   1974        None  Forced air  Central               2 spaces    $727
# 10  1976        None  Forced air  Central               2 spaces    $546
# 11  1989   $60/month  Forced air  Central               2 spaces    $672
# 12  1953        None  Forced air  Central               2 spaces    $625
# 13  2010  $194/month  Forced air  Central               2 spaces    $623
# 14  1951        None        Wall  Central                1 space    $799
# 15  2006        None  Forced air  Central               2 spaces    $568
# 16  2020        None         Gas  Central               2 spaces    $625
# 17  1960   $15/month  Forced air  Central               2 spaces    $809
# 18  1873        None         Gas  Central                1 space  $4,343
# 19  1954        None  Forced air  No Data             Off street    $683
# 20  1987        None  Forced air     None               2 spaces    $691
# 21  1959        None     No Data  No Data        Attached Garage    None
# 22  1960   $18/month  Forced air  Central               2 spaces    None
# 23  1942        None     No Data  No Data  Off street, On street    $681
# 24  1964        None     No Data  No Data        Attached Garage    None
# 25  1967        None     No Data  No Data        Attached Garage    None
# 26  1963        None     No Data  No Data        Attached Garage    None
# 27  1925        None     No Data  No Data        Attached Garage    None
# 28  2000        None   Heat pump  No Data               2 spaces    None
# 29  1960        None     No Data  No Data        Attached Garage    None
# 30  1964   $15/month     No Data  No Data        Attached Garage    None
#
#              6   7                                                  8   \
# 0    $1,088,000   2                                                  4
# 1    $1,425,000   3                                                  4
# 2    $1,060,000   3                                                  3
# 3    $1,088,000   2                                                  4
# 4    $1,425,000   3                                                  4
# 5      $891,000   2                                                  2
# 6      $899,000   3                                                  3
# 7    $1,298,888   2                                                  3
# 8    $1,130,850   2     Master Bedroom on Ground Floor, Walk-in Closet
# 9    $1,247,000   2                                                  4
# 10   $1,790,000   4                                                  4
# 11   $1,225,000   3                                     Walk-in Closet
# 12   $1,475,000   3                                                  5
# 13   $1,449,000   3                                                  4
# 14     $828,888   1                                                  3
# 15   $1,899,000   5                                                  5
# 16   $1,560,000   4                                                  4
# 17   $1,100,000   2                                                  3
# 18  $11,000,000   2                                                  4
# 19   $1,599,888   4                                                  6
# 20   $1,658,888   3                                                  4
# 21   $1,234,236   2                                                  3
# 22   $1,078,574   3   More than One Bedroom on Ground Floor, Master...
# 23     $875,000   1                                                  3
# 24     $688,247   1                                                  2
# 25     $970,808   2                                                  3
# 26   $1,238,188   2                                                  3
# 27   $1,228,121   6                                                  5
# 28   $1,284,895   3                                                  4
# 29     $857,720   2                                                  3
# 30   $1,193,252   2                                                  3
#
#                                                    9            10  \
# 0                 4301 Romilly Way, Fremont, CA 94536   1,797 sqft
# 1                4566 Northdale Dr, Fremont, CA 94536   2,099 sqft
# 2                333 Sunnyslope Dr, Fremont, CA 94536   1,384 sqft
# 3                 4301 Romilly Way, Fremont, CA 94536   1,797 sqft
# 4                4566 Northdale Dr, Fremont, CA 94536   2,099 sqft
# 5                38245 Parkmont Dr, Fremont, CA 94536   1,050 sqft
# 6                 37941 Essanay Pl, Fremont, CA 94536   1,236 sqft
# 7                  3609 Wyndham Dr, Fremont, CA 94536   1,572 sqft
# 8                   3751 Ruskin Pl, Fremont, CA 94536   1,503 sqft
# 9                3112 Mackenzie Pl, Fremont, CA 94536   1,715 sqft
# 10  Price cut: $59K (9/9)2657 Bailey Ct, Fremont, ...   3,281 sqft
# 11                    177 Joan Ter, Fremont, CA 94536   1,824 sqft
# 12              4790 Hazelwood Ave, Fremont, CA 94536   2,360 sqft
# 13  Price cut: $51K (9/4)35673 Embassy Cmn, Fremon...   2,324 sqft
# 14               37109 Dondero Way, Fremont, CA 94536   1,037 sqft
# 15                 1756 Acacia Way, Fremont, CA 94536   3,346 sqft
# 16                        105 E St, Fremont, CA 94536   2,495 sqft
# 17              37843 Granville Dr, Fremont, CA 94536   1,360 sqft
# 18             38555 Overacker Ave, Fremont, CA 94536   2,533 sqft
# 19                38081 Temple Way, Fremont, CA 94536   2,343 sqft
# 20  Price cut: $50K (8/25)2896 Harrisburg Ave, Fre...   2,402 sqft
# 21                  4326 Burke Way, Fremont, CA 94536   1,971 sqft
# 22                  5386 Sayre Ave, Fremont, CA 94536   1,586 sqft
# 23             38066 Stenhammer Dr, Fremont, CA 94536   1,284 sqft
# 24             38003 Stenhammer Dr, Fremont, CA 94536     912 sqft
# 25                4402 Castanos St, Fremont, CA 94536   1,256 sqft
# 26                 4647 Hansen Ave, Fremont, CA 94536   2,028 sqft
# 27              37231 Mission Blvd, Fremont, CA 94536   2,262 sqft
# 28          176 Black Mountain Cir, Fremont, CA 94536   2,380 sqft
# 29                 5194 Morris Way, Fremont, CA 94536   1,080 sqft
# 30                38744 Farwell Dr, Fremont, CA 94536   1,883 sqft
#
#              11    12                                                 13
# 0    6,991 sqft  None  https://www.zillow.com/homedetails/4301-Romill...
# 1   10,798 sqft  None  https://www.zillow.com/homedetails/4566-Northd...
# 2    3,624 sqft  None  https://www.zillow.com/homedetails/333-Sunnysl...
# 3    6,991 sqft  None  https://www.zillow.com/homedetails/4301-Romill...
# 4   10,798 sqft  None  https://www.zillow.com/homedetails/4566-Northd...
# 5    2,848 sqft  None  https://www.zillow.com/homedetails/38245-Parkm...
# 6    2,840 sqft  None  https://www.zillow.com/homedetails/37941-Essan...
# 7    6,947 sqft  None  https://www.zillow.com/homedetails/3609-Wyndha...
# 8    4,347 sqft  None  https://www.zillow.com/homedetails/3751-Ruskin...
# 9    7,705 sqft  None  https://www.zillow.com/homedetails/3112-Macken...
# 10   7,108 sqft  None  https://www.zillow.com/homedetails/2657-Bailey...
# 11   4,072 sqft  None  https://www.zillow.com/homedetails/177-Joan-Te...
# 12   6,133 sqft  None  https://www.zillow.com/homedetails/4790-Hazelw...
# 13   3,937 sqft  None  https://www.zillow.com/homedetails/35673-Embas...
# 14   5,427 sqft  None  https://www.zillow.com/homedetails/37109-Donde...
# 15   7,718 sqft  None  https://www.zillow.com/homedetails/1756-Acacia...
# 16   6,804 sqft  None  https://www.zillow.com/homedetails/105-E-St-Fr...
# 17   9,326 sqft  None  https://www.zillow.com/homedetails/37843-Granv...
# 18   2.04 Acres  None  https://www.zillow.com/homedetails/38555-Overa...
# 19   6,960 sqft  None  https://www.zillow.com/homedetails/38081-Templ...
# 20   6,912 sqft  None  https://www.zillow.com/homedetails/2896-Harris...
# 21   6,098 sqft  None  https://www.zillow.com/homedetails/4326-Burke-...
# 22   7,348 sqft  None  https://www.zillow.com/homedetails/5386-Sayre-...
# 23   5,998 sqft  None  https://www.zillow.com/homedetails/38066-Stenh...
# 24   5,967 sqft  None  https://www.zillow.com/homedetails/38003-Stenh...
# 25   5,837 sqft  None  https://www.zillow.com/homedetails/4402-Castan...
# 26   6,534 sqft  None  https://www.zillow.com/homedetails/4647-Hansen...
# 27   4,660 sqft  None  https://www.zillow.com/homedetails/37231-Missi...
# 28   5,270 sqft  None  https://www.zillow.com/homedetails/176-Black-M...
# 29   6,838 sqft  None  https://www.zillow.com/homedetails/5194-Morris...
# 30   7,840 sqft  None  https://www.zillow.com/homedetails/38744-Farwe...

# %%
tag_list=data_return(links[2])

# %%
tag_list
# Out:
# ['1955',
#  '$18/month',
#  'Forced air',
#  'Central',
#  '2 spaces',
#  '$679',
#  '$1,425,000',
#  ' 3',
#  ' 4',
#  '4566 Northdale Dr,\xa0Fremont, CA 94536',
#  ' 2,099 sqft',
#  '10,798 sqft',
#  'None',
#  'https://www.zillow.com/homedetails/4566-Northdale-Dr-Fremont-CA-94536/25007670_zpid/']

# %%
df=df.append(pd.Series(tag_list),ignore_index=True)

# %%
df
# Out:
#      0          1           2        3         4     5           6   7   8   \
# 0  1965       None  Forced air    Other  2 spaces  $605  $1,088,000   2   4
# 1  1955  $18/month  Forced air  Central  2 spaces  $679  $1,425,000   3   4
#
#                                      9            10           11    12  \
# 0   4301 Romilly Way, Fremont, CA 94536   1,797 sqft   6,991 sqft  None
# 1  4566 Northdale Dr, Fremont, CA 94536   2,099 sqft  10,798 sqft  None
#
#                                                   13
# 0  https://www.zillow.com/homedetails/4301-Romill...
# 1  https://www.zillow.com/homedetails/4566-Northd...

# %%
Year=[]
HOA=[] 
Heating=[]
Cooling=[]
parking=[]
Price_Sqft=[]
Price=[]
bedroom=[]
bathroom=[]
address=[]
house_size=[]
lot_size=[]
Day_on_zillow=[]
url=[]

for i in links:
    tag_list=[]
    tag_list=data_return(i)
    print(tag_list)
    Year.append(tag_list[0])
    HOA.append(tag_list[1])
    Heating.append(tag_list[2])
    Cooling.append(tag_list[3])
    parking.append(tag_list[4])
    Price_Sqft.append(tag_list[5])
    Price.append(tag_list[6])
    bedroom.append(tag_list[7])
    bathroom.append(tag_list[8])
    address.append(tag_list[9])
    house_size.append(tag_list[10])
    lot_size.append(tag_list[11])
    Day_on_zillow.append(tag_list[12])
    url.append(tag_list[13])
    
    #df=pd.DataFrame()
    #df.append(pd.Series(tag_list),ignore_index=True)
    #print(df)
    #print(p)
# Out:
# ['1989', 'None', 'Forced air', 'Central', 'Attached Garage', '$766', '$1,060,000', ' 3', ' 3', '333 Sunnyslope Dr,\xa0Fremont, CA 94536', ' 1,384 sqft', '3,624 sqft', 'None', []]
# ['1965', 'None', 'Forced air', 'Other', '2 spaces', '$605', '$1,088,000', ' 2', ' 4', '4301 Romilly Way,\xa0Fremont, CA 94536', ' 1,797 sqft', '6,991 sqft', 'None', [[...]]]
# ['1955', '$18/month', 'Forced air', 'Central', '2 spaces', '$679', '$1,425,000', ' 3', ' 4', '4566 Northdale Dr,\xa0Fremont, CA 94536', ' 2,099 sqft', '10,798 sqft', 'None', [[...], [...]]]
# ['1983', 'None', 'Forced air', 'No Data', '2 spaces', '$727', '$899,000', ' 3', ' 3', '37941 Essanay Pl,\xa0Fremont, CA 94536', ' 1,236 sqft', '2,840 sqft', 'None', [[...], [...], [...]]]
# ['1976', 'None', 'Forced air', 'Central', 'Attached Garage', '$752', '$1,130,850', ' 2', ' Master Bedroom on Ground Floor, Walk-in Closet', '3751 Ruskin Pl,\xa0Fremont, CA 94536', ' 1,503 sqft', '4,347 sqft', 'None', [[...], [...], [...], [...]]]
# ['1986', 'None', 'Forced air', 'Central', '2 spaces', '$826', '$1,298,888', ' 2', ' 3', '3609 Wyndham Dr,\xa0Fremont, CA 94536', ' 1,572 sqft', '6,947 sqft', 'None', [[...], [...], [...], [...], [...]]]
# ['1963', '$45/month', 'Forced air', 'None', '2 spaces', '$849', '$891,000', ' 2', ' 2', '38245 Parkmont Dr,\xa0Fremont, CA 94536', ' 1,050 sqft', '2,848 sqft', 'None', [[...], [...], [...], [...], [...], [...]]]
# ['1976', 'None', 'Forced air', 'Central', '2 spaces', '$546', '$1,790,000', ' 4', ' 4', 'Price cut: $59K (9/9)2657 Bailey Ct,\xa0Fremont, CA 94536', ' 3,281 sqft', '7,108 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...]]]
# ['2010', '$194/month', 'Forced air', 'Central', '2 spaces', '$623', '$1,449,000', ' 3', ' 4', 'Price cut: $51K (9/4)35673 Embassy Cmn,\xa0Fremont, CA 94536', ' 2,324 sqft', '3,937 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1953', 'None', 'Forced air', 'Central', '2 spaces', '$625', '$1,475,000', ' 3', ' 5', '4790 Hazelwood Ave,\xa0Fremont, CA 94536', ' 2,360 sqft', '6,133 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1989', '$60/month', 'Forced air', 'Central', '2 spaces', '$672', '$1,225,000', ' 3', ' Walk-in Closet', '177 Joan Ter,\xa0Fremont, CA 94536', ' 1,824 sqft', '4,072 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1974', 'None', 'Forced air', 'Central', '2 spaces', '$727', '$1,247,000', ' 2', ' 4', '3112 Mackenzie Pl,\xa0Fremont, CA 94536', ' 1,715 sqft', '7,705 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['2020', 'None', 'Gas', 'Central', '2 spaces', '$625', '$1,560,000', ' 4', ' 4', '105 E St,\xa0Fremont, CA 94536', ' 2,495 sqft', '6,804 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['2006', 'None', 'Forced air', 'Central', '2 spaces', '$568', '$1,899,000', ' 5', ' 5', '1756 Acacia Way,\xa0Fremont, CA 94536', ' 3,346 sqft', '7,718 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1951', 'None', 'Wall', 'Central', '1 space', '$799', '$828,888', ' 1', ' 3', '37109 Dondero Way,\xa0Fremont, CA 94536', ' 1,037 sqft', '5,427 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1954', 'None', 'Forced air', 'No Data', 'Off street', '$683', '$1,599,888', ' 4', ' 6', '38081 Temple Way,\xa0Fremont, CA 94536', ' 2,343 sqft', '6,960 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1960', '$15/month', 'Forced air', 'Central', '2 spaces', '$809', '$1,100,000', ' 2', ' 3', '37843 Granville Dr,\xa0Fremont, CA 94536', ' 1,360 sqft', '9,326 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1987', 'None', 'Forced air', 'None', '2 spaces', '$691', '$1,658,888', ' 3', ' 4', 'Price cut: $50K (8/25)2896 Harrisburg Ave,\xa0Fremont, CA 94536', ' 2,402 sqft', '6,912 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1873', 'None', 'Gas', 'Central', '1 space', '$4,343', '$11,000,000', ' 2', ' 4', '38555 Overacker Ave,\xa0Fremont, CA 94536', ' 2,533 sqft', '2.04 acres', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1942', 'None', 'No Data', 'No Data', 'Off street, On street', '$681', '$875,000', ' 1', ' 3', '38066 Stenhammer Dr,\xa0Fremont, CA 94536', ' 1,284 sqft', '5,998 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1925', 'None', 'No Data', 'No Data', 'Attached Garage', 'None', '$1,228,121', ' 6', ' 5', '37231 Mission Blvd,\xa0Fremont, CA 94536', ' 2,262 sqft', '4,660 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['2000', 'None', 'Heat pump', 'No Data', '2 spaces', 'None', '$1,284,895', ' 3', ' 4', '176 Black Mountain Cir,\xa0Fremont, CA 94536', ' 2,380 sqft', '5,270 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1960', 'None', 'No Data', 'No Data', 'Attached Garage', 'None', '$857,720', ' 2', ' 3', '5194 Morris Way,\xa0Fremont, CA 94536', ' 1,080 sqft', '6,838 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1963', 'None', 'No Data', 'No Data', 'Attached Garage', 'None', '$1,238,188', ' 2', ' 3', '4647 Hansen Ave,\xa0Fremont, CA 94536', ' 2,028 sqft', '6,534 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1967', 'None', 'No Data', 'No Data', 'Attached Garage', 'None', '$970,808', ' 2', ' 3', '4402 Castanos St,\xa0Fremont, CA 94536', ' 1,256 sqft', '5,837 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1964', 'None', 'No Data', 'No Data', 'Attached Garage', 'None', '$688,247', ' 1', ' 2', '38003 Stenhammer Dr,\xa0Fremont, CA 94536', ' 912 sqft', '5,967 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1959', 'None', 'No Data', 'No Data', 'No Data', 'None', '$1,235,290', ' 2', ' 3', '4326 Burke Way,\xa0Fremont, CA 94536', ' 1,971 sqft', '6,098 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1960', '$18/month', 'Forced air', 'Central', '2 spaces', 'None', '$1,078,574', ' 3', ' More than One Bedroom on Ground Floor, Master Suite / Retreate - 2+', '5386 Sayre Ave,\xa0Fremont, CA 94536', ' 1,586 sqft', '7,348 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]
# ['1964', '$15/month', 'No Data', 'No Data', 'Attached Garage', 'None', '$1,193,252', ' 2', ' 3', '38744 Farwell Dr,\xa0Fremont, CA 94536', ' 1,883 sqft', '7,840 sqft', 'None', [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]]

# %%
df['Year']=Year
df['url']=url
df['Day_on_zillow']=Day_on_zillow
df['lot_size']=lot_size
df['house_size']=house_size
df['address']=address
df['bathroom']=bathroom
df['bedroom']=bedroom
df['Price/Sqft']=Price_Sqft
df['parking']=parking
df['Cooling']=Cooling
df['Heating']=Heating
df['HOA']=HOA

# %%
df
